# %%
# !pip install reportlab
from reportlab.lib.pagesizes import letter
from reportlab.pdfgen import canvas

# Choose a name for your file
pdf_path = "/content/my_first_project.pdf"

# Create the PDF
c = canvas.Canvas(pdf_path, pagesize=letter)

# Add text to it
c.drawString(100, 750, "My First AI Project")
c.drawString(100, 730, "Created by Reshma 🌸")
c.drawString(100, 700, "This is a simple demo PDF created using Python and ReportLab.")

# Save the PDF
c.save()

print("✅ PDF created successfully at:", pdf_path)
from google.colab import files
files.download("/content/my_first_project.pdf")
# Out:
# ...
# ✅ PDF created successfully at: /content/my_first_project.pdf
